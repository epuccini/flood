# %%
(princ "HELE")
# Out:
# "HELE"
# HELE

# %%
(asdf:load-system :ga)
# Out:
# T

# %%
(ga:main)
# Out:
# NIL
# (1 0 0 1 1 0 0 0 )
# (A B C D E F G H )
#
#  Value: 152
#
# (1 0 0 1 1 0 0 1 )
# (A B C D E F G H )
#
#  Value: 153
#
# (0 0 0 1 1 0 0 1 )
# (A B C D E F G H )
#
#  Value: 25
#
# (1 0 1 0 1 1 1 0 )
# (A B C D E F G H )
#
#  Value: 174
#
# (1 0 0 1 1 1 1 0 )
# (A B C D E F G H )
#
#  Value: 158
#
# (0 1 0 0 1 1 1 1 )
# (A B C D E F G H )
#
#  Value: 79
#
# (1 0 0 1 1 1 0 0 )
# (A B C D E F G H )
#
#  Value: 156
#
# (1 0 0 0 1 0 1 0 )
# (A B C D E F G H )
#
#  Value: 138
#
# (1 0 1 0 1 0 1 1 )
# (A B C D E F G H )
#
#  Value: 171
#
# (0 1 0 1 1 0 1 0 )
# (A B C D E F G H )
#
#  Value: 90
#
# (0 1 0 1 0 1 0 0 )
# (A B C D E F G H )
#
#  Value: 84
#
# (1 1 0 1 1 0 1 1 )
# (A B C D E F G H )
#
#  Value: 219
#
# (1 0 0 1 1 1 0 0 )
# (A B C D E F G H )
#
#  Value: 156
#
# (1 1 1 1 1 1 0 0 )
# (A B C D E F G H )
#
#  Value: 252
#
# (1 1 0 1 1 0 1 1 )
# (A B C D E F G H )
#
#  Value: 219
#
# (0 1 0 0 1 1 0 1 )
# (E B C A E F G D )
#
#  Value: 77
#
# (0 1 0 0 1 1 1 0 )
# (E B C A E F G H )
#
#  Value: 78
#
# (1 0 0 0 1 1 1 0 )
# (A B C D E F G H )
#
#  Value: 142
#
# (1 0 0 0 1 1 1 0 )
# (A B C D E F G H )
#
#  Value: 142
#
# (0 1 0 0 0 1 1 0 )
# (E B C A H F G H )
#
#  Value: 70
#
# (0 1 0 0 0 1 1 1 )
# (E B C A H F G H )
#
#  Value: 71
#
# (0 1 0 0 0 1 1 1 )
# (E B C A H F G D )
#
#  Value: 71
#
# (1 1 0 0 1 0 1 0 )
# (A B C A E F G H )
#
#  Value: 202
#
# (1 1 1 1 0 0 0 1 )
# (A B C D H F G H )
#
#  Value: 241
#
# (0 1 1 0 1 0 1 1 )
# (E B C A E F G D )
#
#  Value: 107
#
# (1 0 1 0 1 0 1 1 )
# (A B C A E F G D )
#
#  Value: 171
#
# (0 1 0 0 0 0 0 0 )
# (A B D C E F G H )
#
#  Value: 64
#
# (0 0 1 0 0 0 0 0 )
# (E B C C E F G H )
#
#  Value: 32
#
# (0 0 1 0 0 0 0 1 )
# (E B C C E F G H )
#
#  Value: 33
#
# (0 1 0 0 0 0 0 1 )
# (A B D C E F G H )
#
#  Value: 65
#
# (1 1 0 0 0 0 0 0 )
# (A B D C E F G H )
#
#  Value: 192
#
# (0 1 0 0 0 0 0 1 )
# (A B C C E F G D )
#
#  Value: 65
#
# (0 0 1 1 0 0 0 1 )
# (E B C D C F G D )
#
#  Value: 49
#
# (1 1 0 0 0 0 0 1 )
# (A B C C C F G D )
#
#  Value: 193
#
# (1 1 1 1 0 0 0 1 )
# (B A C D E F G H )
#
#  Value: 241
#
# (0 0 1 1 0 0 0 1 )
# (E B C D E F G H )
#
#  Value: 49
#
# (0 1 0 0 0 0 1 1 )
# (A B C A E F G D )
#
#  Value: 67
#
# (1 1 0 0 0 0 0 0 )
# (B A C A E F G C )
#
#  Value: 192
#
# (1 0 0 0 0 1 0 1 )
# (B F C A E A G H )
#
#  Value: 133
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 1 )
# (A B C D E F G H )
#
#  Value: 65
#
# (0 1 0 0 0 0 0 0 )
# (E B C A E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C A E F G C )
#
#  Value: 64
#
# (0 1 0 1 0 0 0 0 )
# (A B D D E F G C )
#
#  Value: 80
#
# (0 1 0 0 0 0 0 0 )
# (A B C A E F G C )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B D D E F G C )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C A E F G C )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 1 )
# (A B C D E F G H )
#
#  Value: 65
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G C )
#
#  Value: 64
#
# (0 1 0 0 0 1 0 0 )
# (A B C D E A G H )
#
#  Value: 68
#
# (0 1 0 0 0 0 0 0 )
# (A B C B E F G C )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C B E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 1 )
# (E B C D E F G H )
#
#  Value: 65
#
# (0 0 0 0 0 0 0 0 )
# (A A C B E F G H )
#
#  Value: 0
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B E D C F G H )
#
#  Value: 64
#
# (0 0 0 0 0 0 0 0 )
# (A A C B E F G H )
#
#  Value: 0
#
# (0 1 0 0 0 0 0 1 )
# (A B C D C F G H )
#
#  Value: 65
#
# (0 1 0 0 0 0 0 0 )
# (A B C D C F G H )
#
#  Value: 64
#
# (0 0 0 0 0 0 0 0 )
# (A A C B C F G H )
#
#  Value: 0
#
# (0 1 0 0 0 0 0 0 )
# (D B C G E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C G E F D H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 1 )
# (D B C G E F G H )
#
#  Value: 65
#
# (0 1 0 0 0 0 0 1 )
# (A B C G E F G H )
#
#  Value: 65
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B C D E F F H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B C G C F F H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B E E C F F H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C E C F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C E C F F H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B E D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C E C F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C E C D F H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C E C D G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B F G E D G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B E D E D G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B F G E F F H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B F G E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B E D C A G G )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B E D E F F G )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B F G C A G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B F G E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F F G )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B F G E F F H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B F G E A G G )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B F G E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B E D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B E D E A F G )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B E D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (D B F G E A F G )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B E G E A G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B E G E F G G )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C D E F G H )
#
#  Value: 64
#
# (0 1 0 0 0 0 0 0 )
# (A B C G E A G G )
#
#  Value: 64

# %%
(defconstant +null+ (code-char 0))

(defun read-null-terminated-ascii (in)
  (with-output-to-string (s)
    (loop for char = (code-char (read-byte in))
          until (char= char +null+) do (write-char char s))))
# Out:
# +NULL+
# READ-NULL-TERMINATED-ASCII

# %%
(read-null-terminated-ascii "/⁨Users⁩/edward/Downloads⁩/words.txt")
# Out:
# TYPE-ERROR: The value
#   "/⁨Users⁩/edward/Downloads⁩/words.txt"
# is not of type
#   STREAM
# The value
#   "/⁨Users⁩/edward/Downloads⁩/words.txt"
# is not of type
#   STREAM

# %%
(asdf:load-system :ieee-floats)
# Out:
# T

# %%
(asdf:load-system :cl-binary)

# %%
(with-open-input-binary-stream (in #(#x01 #x23 #x45 #x67))
  (format t "~A~%" (read-u32 in)))
